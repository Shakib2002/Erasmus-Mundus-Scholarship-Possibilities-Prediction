# %% [markdown]
# python -m pip install "pymongo[srv]==3.12"

# %%
import pandas as pd

# %%
df = pd.read_csv("Graduate.csv")
df.head()
# Out:
#    GRE_Score  TOEFL_Score  IELTS_Score  CGPA  University_Rating  SOP  LOR  \
# 0      295.0         96.0          7.5  2.93                  2  4.9  1.7
# 1      340.0        119.0          9.0  3.76                  3  4.1  1.7
# 2      336.0         96.0          7.5  3.12                  1  3.2  1.8
# 3      337.0        108.0          8.0  2.11                  4  3.4  1.3
# 4      323.0         98.0          7.5  3.40                  1  1.1  1.3
#
#    Research  Publications  Work_Experience_Months Internship  \
# 0         0             1                       8         No
# 1         0             1                      31        Yes
# 2         1             2                      29        Yes
# 3         0             0                      35        Yes
# 4         0             1                      16        Yes
#
#    Leadership_Score  Awards_Count     Country Target_Program  Graduation_Year  \
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['GRE_Score', 'TOEFL_Score', 'IELTS_Score', 'CGPA', 'University_Rating',
#        'SOP', 'LOR', 'Research', 'Publications', 'Work_Experience_Months',
#        'Internship', 'Leadership_Score', 'Awards_Count', 'Country',
#        'Target_Program', 'Graduation_Year', 'Scholarship_Awarded'],
#       dtype='object')

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'GRE_Score': 295.0,
#   'TOEFL_Score': 96.0,
#   'IELTS_Score': 7.5,
#   'CGPA': 2.93,
#   'University_Rating': 2,
#   'SOP': 4.9,
#   'LOR': 1.7,
#   'Research': 0,
#   'Publications': 1,
#   'Work_Experience_Months': 8,
#   'Internship': 'No',
#   'Leadership_Score': 5,
#   'Awards_Count': 0,
#   'Country': 'Nepal',
#   'Target_Program': 'EMJM Cyber',
#   'Graduation_Year': 2024,
#   'Scholarship_Awarded': 'No'},
#  {'GRE_Score': 340.0,
#   'TOEFL_Score': 119.0,
#   'IELTS_Score': 9.0,
#   'CGPA': 3.76,
#   'University_Rating': 3,
#   'SOP': 4.1,
#   'LOR': 1.7,
#   'Research': 0,
#   'Publications': 1,
#   'Work_Experience_Months': 31,
#   'Internship': 'Yes',
#   'Leadership_Score': 4,
#   'Awards_Count': 0,
#   'Country': 'Pakistan',
#   'Target_Program': 'EMJM Cyber',
#   'Graduation_Year': 2025,
#   'Scholarship_Awarded': 'No'},
#  {'GRE_Score': 336.0,
#   'TOEFL_Score': 96.0,
#   'IELTS_Score': 7.5,
#   'CGPA': 3.12,
#   'University_Rating': 1,
#   'SOP': 3.2,
# ...

# %%
DD_NAME = "scholarship"
COLLECTION_NAME = "scholarship_data"
CONNECTION_URL = "mongodb+srv://helloshakibx_db_user:NsqPrMAR5FfIMmo8@cluster0.qt4bcek.mongodb.net"

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DD_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pymongo
# ----> 3 client = pymongo.MongoClient(CONNECTION_URL)
#       4 data_base = client[DD_NAME]
#       5 collection = data_base[COLLECTION_NAME]
#
# File c:\Users\HP\Miniconda3\envs\scholarship\lib\site-packages\pymongo\synchronous\mongo_client.py:841, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     839 username = opts.get("username", username)
#     840 password = opts.get("password", password)
# --> 841 self._options = options = ClientOptions(username, password, dbase, opts, _IS_SYNC)
#     843 self._default_database_name = dbase
#     844 self._lock = _create_lock()
#
# ...

# %%
import pymongo
import certifi

# certifi ব্যবহার করে SSL এরর ফিক্স করা হয়েছে
client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())

# ডাটাবেস এবং কালেকশন তৈরি
data_base = client[DD_NAME]
collection = data_base[COLLECTION_NAME]

# ডেটাবেসে ডেটা ইনসার্ট করা
rec = collection.insert_many(data)

print(f"Total {len(rec.inserted_ids)} records inserted successfully!")
# Out:
# Total 1000 records inserted successfully!

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i} : {j}")
# Out:
# 0 : {'_id': ObjectId('6a5c93656eed02b82b98192c'), 'GRE_Score': 295.0, 'TOEFL_Score': 96.0, 'IELTS_Score': 7.5, 'CGPA': 2.93, 'University_Rating': 2, 'SOP': 4.9, 'LOR': 1.7, 'Research': 0, 'Publications': 1, 'Work_Experience_Months': 8, 'Internship': 'No', 'Leadership_Score': 5, 'Awards_Count': 0, 'Country': 'Nepal', 'Target_Program': 'EMJM Cyber', 'Graduation_Year': 2024, 'Scholarship_Awarded': 'No'}
# 1 : {'_id': ObjectId('6a5c93656eed02b82b98192d'), 'GRE_Score': 340.0, 'TOEFL_Score': 119.0, 'IELTS_Score': 9.0, 'CGPA': 3.76, 'University_Rating': 3, 'SOP': 4.1, 'LOR': 1.7, 'Research': 0, 'Publications': 1, 'Work_Experience_Months': 31, 'Internship': 'Yes', 'Leadership_Score': 4, 'Awards_Count': 0, 'Country': 'Pakistan', 'Target_Program': 'EMJM Cyber', 'Graduation_Year': 2025, 'Scholarship_Awarded': 'No'}
# ...

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id  GRE_Score  TOEFL_Score  IELTS_Score  CGPA  \
# 0  6a5c93656eed02b82b98192c      295.0         96.0          7.5  2.93
# 1  6a5c93656eed02b82b98192d      340.0        119.0          9.0  3.76
# 2  6a5c93656eed02b82b98192e      336.0         96.0          7.5  3.12
# 3  6a5c93656eed02b82b98192f      337.0        108.0          8.0  2.11
# 4  6a5c93656eed02b82b981930      323.0         98.0          7.5  3.40
#
#    University_Rating  SOP  LOR  Research  Publications  \
# 0                  2  4.9  1.7         0             1
# 1                  3  4.1  1.7         0             1
# 2                  1  3.2  1.8         1             2
# 3                  4  3.4  1.3         0             0
# 4                  1  1.1  1.3         0             1
#
#    Work_Experience_Months Internship  Leadership_Score  Awards_Count  \
# 0                       8         No                 5             0
# ...

# %%
if "_id" in df.columns.to_list():
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#    GRE_Score  TOEFL_Score  IELTS_Score  CGPA  University_Rating  SOP  LOR  \
# 0      295.0         96.0          7.5  2.93                  2  4.9  1.7
# 1      340.0        119.0          9.0  3.76                  3  4.1  1.7
# 2      336.0         96.0          7.5  3.12                  1  3.2  1.8
# 3      337.0        108.0          8.0  2.11                  4  3.4  1.3
# 4      323.0         98.0          7.5  3.40                  1  1.1  1.3
#
#    Research  Publications  Work_Experience_Months Internship  \
# 0         0             1                       8         No
# 1         0             1                      31        Yes
# 2         1             2                      29        Yes
# 3         0             0                      35        Yes
# 4         0             1                      16        Yes
#
#    Leadership_Score  Awards_Count     Country Target_Program  Graduation_Year  \
# ...
